# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("E:\\PYTHON Durga Fill\\Training_Data_Set.csv")
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# 1                  2012           7                 1242          51.0
# 2                  2014           5                 1995         105.0
# 3                  2011           8                 1618         140.0
# 4                  2012           7                 2993         180.0
# ...                 ...         ...                  ...           ...
# 53510              2014           5                 1598          77.0
# 53511              2009          10                 1900          77.0
# 53512              2015           4                 1995         105.0
# 53513              2011           8                11950          93.0
# 53514              2008          11                 2993         173.0
#
#       body_type  Vroom Audit Rating transmission  door_count  seat_count  \
# 0       compact                   8          man         NaN         NaN
# 1           NaN                   6          man         4.0         4.0
# 2           NaN                   7         auto         4.0         5.0
# 3           NaN                   7          man         4.0         5.0
# 4           NaN                   7         auto         4.0         5.0
# ...         ...                 ...          ...         ...         ...
# 53510       NaN                   4          man         4.0         5.0
# 53511       NaN                   8          man         5.0         5.0
# 53512       NaN                   4         auto         4.0         5.0
# 53513   compact                   5          man         NaN         NaN
# 53514       NaN                   4         auto         5.0         5.0
#
#       fuel_type       Price
# 0        petrol   543764.25
# 1        petrol   401819.25
# 2        diesel  2392855.50
# 3        petrol   958606.50
# 4        diesel  3085561.50
# ...         ...         ...
# 53510    diesel  1342996.50
# 53511    diesel   510732.75
# 53512    diesel  2008123.50
# 53513    diesel   874352.25
# 53514    diesel  1576610.25
#
# [53515 rows x 17 columns]

# %%
df.isnull()
# Out:
#           Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0      False  False  False     False       True       False             False
# 1      False  False  False     False      False       False             False
# 2      False  False  False     False      False       False             False
# 3      False  False  False     False      False       False             False
# 4      False  False  False     False      False       False             False
# ...      ...    ...    ...       ...        ...         ...               ...
# 53510  False  False  False     False      False       False             False
# 53511  False  False  False     False      False       False             False
# 53512  False  False  False     False      False       False             False
# 53513  False  False  False     False      False       False             False
# 53514  False  False  False     False      False       False             False
#
#        Age of car  engine_displacement  engine_power  body_type  \
# 0           False                False         False      False
# 1           False                False         False       True
# 2           False                False         False       True
# 3           False                False         False       True
# 4           False                False         False       True
# ...           ...                  ...           ...        ...
# 53510       False                False         False       True
# 53511       False                False         False       True
# 53512       False                False         False       True
# 53513       False                False         False      False
# 53514       False                False         False       True
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                   False         False        True        True      False
# 1                   False         False       False       False      False
# 2                   False         False       False       False      False
# 3                   False         False       False       False      False
# 4                   False         False       False       False      False
# ...                   ...           ...         ...         ...        ...
# 53510               False         False       False       False      False
# 53511               False         False       False       False      False
# 53512               False         False       False       False      False
# 53513               False         False        True        True      False
# 53514               False         False       False       False      False
#
#        Price
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 53510  False
# 53511  False
# 53512  False
# 53513  False
# 53514  False
#
# [53515 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type', 'Price'],
#       dtype='object')

# %%
df.drop(columns='body_type',inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance               1211
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power           1439
# Vroom Audit Rating        0
# transmission              0
# door_count             7534
# seat_count             8511
# fuel_type                 0
# Price                     0
# dtype: int64

# %%
df['Distance '].mean()
# Out:
# 94546.2624464668

# %%
df['Distance '].median()
# Out:
# 65520.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['Distance '].fillna(df['Distance '].median(),inplace=True)

# %%
df['Distance '].isnull().sum()
# Out:
# 0

# %%
df['engine_power'].mean()
# Out:
# 100.44834472693755

# %%
df['engine_power'].median()
# Out:
# 91.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['engine_power'].fillna(df['engine_power'].mean(),inplace=True)

# %%
df['engine_power'].isnull().sum()
# Out:
# 0

# %%
df['door_count'].mean()
# Out:
# 3.973010591331202

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['door_count'].fillna(df['door_count'].mean(),inplace=True)

# %%
df['door_count'].isnull().sum()
# Out:
# 0

# %%
df['seat_count'].mean()
# Out:
# 4.886099013421029

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)

# %%
df['seat_count'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad    65520.0          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# 1                  2012           7                 1242          51.0
# 2                  2014           5                 1995         105.0
# 3                  2011           8                 1618         140.0
# 4                  2012           7                 2993         180.0
# ...                 ...         ...                  ...           ...
# 53510              2014           5                 1598          77.0
# 53511              2009          10                 1900          77.0
# 53512              2015           4                 1995         105.0
# 53513              2011           8                11950          93.0
# 53514              2008          11                 2993         173.0
#
#        Vroom Audit Rating transmission  door_count  seat_count fuel_type  \
# 0                       8          man    3.973011    4.886099    petrol
# 1                       6          man    4.000000    4.000000    petrol
# 2                       7         auto    4.000000    5.000000    diesel
# 3                       7          man    4.000000    5.000000    petrol
# 4                       7         auto    4.000000    5.000000    diesel
# ...                   ...          ...         ...         ...       ...
# 53510                   4          man    4.000000    5.000000    diesel
# 53511                   8          man    5.000000    5.000000    diesel
# 53512                   4         auto    4.000000    5.000000    diesel
# 53513                   5          man    3.973011    4.886099    diesel
# 53514                   4         auto    5.000000    5.000000    diesel
#
#             Price
# 0       543764.25
# 1       401819.25
# 2      2392855.50
# 3       958606.50
# 4      3085561.50
# ...           ...
# 53510  1342996.50
# 53511   510732.75
# 53512  2008123.50
# 53513   874352.25
# 53514  1576610.25
#
# [53515 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
# data type change
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Maker']=le.fit_transform(df['Maker'])

# %%
df['model']=le.fit_transform(df['model'])

# %%
df['Location']=le.fit_transform(df['Location'])
df['Location'].dtypes
# Out:
# dtype('int32')

# %%
df['Owner Type']=le.fit_transform(df['Owner Type'])
df['Owner Type'].dtypes
# Out:
# dtype('int32')

# %%
df['transmission']=le.fit_transform(df['transmission'])
df['transmission'].dtypes
# Out:
# dtype('int32')

# %%
df['fuel_type']=le.fit_transform(df['fuel_type'])
df['fuel_type'].dtypes
# Out:
# dtype('int32')

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int32
# model                    int32
# Location                 int32
# Distance               float64
# Owner Type               int32
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int32
# door_count             float64
# seat_count             float64
# fuel_type                int32
# Price                  float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
plt.show()

# %%
z=(df-df.mean())/df.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813  -0.104123    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.242749    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.175767    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.183294    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.126130   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.236935   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   0.476186   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.251007    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655   4.043199    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   0.176578   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0             -9.979547    9.979547             0.040059      1.041028
# 1              0.342318   -0.342318            -0.442379     -1.105807
# 2              0.772396   -0.772396             0.060773      0.101788
# 3              0.127279   -0.127279            -0.191137      0.884488
# 4              0.342318   -0.342318             0.727634      1.779003
# ...                 ...         ...                  ...           ...
# 53510          0.772396   -0.772396            -0.204501     -0.524372
# 53511         -0.302798    0.302798            -0.002706     -0.524372
# 53512          0.987435   -0.987435             0.060773      0.101788
# 53513          0.127279   -0.127279             6.712674     -0.166566
# 53514         -0.517837    0.517837             0.727634      1.622463
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                1.411249      0.675882    0.000000    0.000000   1.030407
# 1                0.001146      0.675882    0.039312   -1.712223   1.030407
# 2                0.706198     -1.479521    0.039312    0.220093  -0.970472
# 3                0.706198      0.675882    0.039312    0.220093   1.030407
# 4                0.706198     -1.479521    0.039312    0.220093  -0.970472
# ...                   ...           ...         ...         ...        ...
# 53510           -1.408957      0.675882    0.039312    0.220093  -0.970472
# 53511            1.411249      0.675882    1.495881    0.220093  -0.970472
# 53512           -1.408957     -1.479521    0.039312    0.220093  -0.970472
# 53513           -0.703905      0.675882    0.000000    0.000000  -0.970472
# 53514           -1.408957     -1.479521    1.495881    0.220093  -0.970472
#
#           Price
# 0     -0.656655
# 1     -0.824805
# 2      1.533806
# 3     -0.165226
# 4      2.354395
# ...         ...
# 53510  0.290127
# 53511 -0.695784
# 53512  1.078046
# 53513 -0.265035
# 53514  0.566870
#
# [53515 rows x 16 columns]

# %%
df1=df[(z>-2)&(z<2)]

# %%
df1.boxplot()
plt.show()

# %%
z=(df1-df1.mean())/df1.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813  -0.219133    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.711934    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.473818    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.500579    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.297365   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.691267   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   1.843806   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.741290    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655        NaN    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   0.778733   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                   NaN         NaN             0.299406      1.532269
# 1              0.258592   -0.258592            -0.972707     -1.289604
# 2              0.817382   -0.817382             0.354026      0.297699
# 3             -0.020804    0.020804            -0.310221      1.326507
# 4              0.258592   -0.258592             2.112431      2.502287
# ...                 ...         ...                  ...           ...
# 53510          0.817382   -0.817382            -0.345460     -0.525347
# 53511         -0.579594    0.579594             0.186643     -0.525347
# 53512          1.096778   -1.096778             0.354026      0.297699
# 53513         -0.020804    0.020804                  NaN     -0.055035
# 53514         -0.858990    0.858990             2.112431      2.296526
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                1.411249      0.675882   -0.470253   -0.032198   1.030407
# 1                0.001146      0.675882   -0.397440   -3.218213   1.030407
# 2                0.706198     -1.479521   -0.397440    0.377339  -0.970472
# 3                0.706198      0.675882   -0.397440    0.377339   1.030407
# 4                0.706198     -1.479521   -0.397440    0.377339  -0.970472
# ...                   ...           ...         ...         ...        ...
# 53510           -1.408957      0.675882   -0.397440    0.377339  -0.970472
# 53511            1.411249      0.675882    2.300414    0.377339  -0.970472
# 53512           -1.408957     -1.479521   -0.397440    0.377339  -0.970472
# 53513           -0.703905      0.675882   -0.470253   -0.032198  -0.970472
# 53514           -1.408957     -1.479521    2.300414    0.377339  -0.970472
#
#           Price
# 0     -0.697782
# 1     -0.923688
# 2      2.245066
# 3     -0.037556
# 4           NaN
# ...         ...
# 53510  0.574205
# 53511 -0.750352
# 53512  1.632761
# 53513 -0.171647
# 53514  0.946003
#
# [53515 rows x 16 columns]

# %%
df2=df1[(z>-2)&(z<2)]

# %%
df2.boxplot()
plt.show()

# %%
z=(df2-df2.mean())/df2.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813  -0.125029    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.705366    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.424954    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.456468    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.217158   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.681028   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   2.304350   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.739937    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655        NaN    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   1.050088   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                   NaN         NaN             0.848838      1.964496
# 1              0.193675   -0.193675            -1.135804     -1.382672
# 2              0.806219   -0.806219             0.934051      0.500110
# 3             -0.112597    0.112597            -0.102251      1.720432
# 4              0.193675   -0.193675                  NaN           NaN
# ...                 ...         ...                  ...           ...
# 53510          0.806219   -0.806219            -0.157227     -0.476147
# 53511         -0.725141    0.725141             0.672914     -0.476147
# 53512          1.112491   -1.112491             0.934051      0.500110
# 53513         -0.112597    0.112597                  NaN      0.081714
# 53514         -1.031413    1.031413                  NaN           NaN
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                1.411249      0.675882   -2.118321   -2.135774   1.030407
# 1                0.001146      0.675882    0.472061         NaN   1.030407
# 2                0.706198     -1.479521    0.472061    0.468204  -0.970472
# 3                0.706198      0.675882    0.472061    0.468204   1.030407
# 4                0.706198     -1.479521    0.472061    0.468204  -0.970472
# ...                   ...           ...         ...         ...        ...
# 53510           -1.408957      0.675882    0.472061    0.468204  -0.970472
# 53511            1.411249      0.675882         NaN    0.468204  -0.970472
# 53512           -1.408957     -1.479521    0.472061    0.468204  -0.970472
# 53513           -0.703905      0.675882   -2.118321   -2.135774  -0.970472
# 53514           -1.408957     -1.479521         NaN    0.468204  -0.970472
#
#           Price
# 0     -0.668588
# 1     -0.934225
# 2           NaN
# 3      0.107752
# 4           NaN
# ...         ...
# 53510  0.827104
# 53511 -0.730403
# 53512  2.071829
# 53513 -0.049922
# 53514  1.264291
#
# [53515 rows x 16 columns]

# %%
df3=df2[(z>-2)&(z<2)]

# %%
df3.boxplot()
plt.show()

# %%
df3.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                4252
# Owner Type                 0
# manufacture_year        5832
# Age of car              5832
# engine_displacement     6224
# engine_power            6848
# Vroom Audit Rating         0
# transmission               0
# door_count             19707
# seat_count             14691
# fuel_type                  0
# Price                   6983
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
data=pd.DataFrame(ss.fit_transform(df3),columns=df3.columns)
data
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.741111  0.057313 -0.852857  1.257948  -0.252008    1.335797
# 1     -1.740981  0.515634 -0.549365 -0.954388  -0.842436   -1.341659
# 2     -1.740787  0.057313  0.209363 -0.638340  -0.743335   -1.341659
# 3     -1.740463  0.973955 -1.459840 -1.586483  -1.064397   -0.449174
# 4     -1.740268  0.515634  1.575075 -1.270435  -1.062733   -1.341659
# ...         ...       ...       ...       ...        ...         ...
# 19787  1.729064  0.973955 -1.763331  0.941900  -0.509393   -1.341659
# 19788  1.729194 -2.234292 -0.094128  1.257948   2.193183    1.335797
# 19789  1.729388  0.515634  0.361109 -0.322292  -0.860592   -1.341659
# 19790  1.729518  0.515634  0.361109  1.257948  -1.064397   -0.449174
# 19791  1.729842  0.515634 -0.549365 -0.322292  -0.522225   -0.449174
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0             -0.375196    0.375196            -0.053511      2.070227
# 1              1.063789   -1.063789             1.023444      0.798729
# 2              1.063789   -1.063789            -0.108897      0.205363
# 3              1.063789   -1.063789            -1.961259     -1.701885
# 4              1.063789   -1.063789            -1.348934     -0.430386
# ...                 ...         ...                  ...           ...
# 19787          0.704043   -0.704043             0.500351     -0.769453
# 19788         -0.015450    0.015450             1.023444      1.222562
# 19789          1.063789   -1.063789            -1.348934     -0.599920
# 19790          1.063789   -1.063789            -1.348934     -0.599920
# 19791          0.704043   -0.704043            -0.115051     -0.599920
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                0.708879      0.552134         0.0         0.0   0.995664
# 1               -1.397536      0.552134         0.0         0.0  -1.004355
# 2               -0.695398      0.552134         0.0         0.0  -1.004355
# 3               -1.397536      0.552134         0.0         0.0   0.995664
# 4               -0.695398      0.552134         0.0         0.0   0.995664
# ...                   ...           ...         ...         ...        ...
# 19787           -1.397536     -1.811153         0.0         0.0   0.995664
# 19788            0.708879      0.552134         0.0         0.0  -1.004355
# 19789           -0.695398      0.552134         0.0         0.0   0.995664
# 19790           -1.397536      0.552134         0.0         0.0   0.995664
# 19791           -1.397536      0.552134         0.0         0.0  -1.004355
#
#           Price
# 0     -0.180869
# 1      1.215133
# 2      0.780319
# 3     -0.624000
# 4      0.328241
# ...         ...
# 19787  0.689499
# 19788  1.999186
# 19789 -0.140465
# 19790 -0.527975
# 19791  0.736220
#
# [19792 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
X=data[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
       'fuel_type']]
y=data['Price']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.7938743272701085

# %%
model.coef_
# Out:
# array([ 0.00232616, -0.16434665,  0.09488156,  0.00159258, -0.37440959,
#         0.00227178,  0.17090213, -0.17090213,  0.11309737,  0.45805637,
#         0.00048827, -0.11514674,  0.        ,  0.        , -0.14982083])

# %%
model.intercept_
# Out:
# 1.830374965475839e-15

# %%
y_predict=pd.DataFrame(model.predict(X))
y_predict
# Out:
#               0
# 0      0.606586
# 1      1.101365
# 2      0.812560
# 3     -0.758848
# 4      0.254299
# ...         ...
# 19787 -0.130703
# 19788  0.303892
# 19789 -0.004642
# 19790  0.075866
# 19791  0.100199
#
# [19792 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y,y_predict)
mse
# Out:
# 0.20612567272989152

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y,y_predict)
mae
# Out:
# 0.35889656274112464

# %%
import numpy as np
import pandas as pd

# %%
df_test=pd.read_csv("E:\\PYTHON Durga Fill\\Test_Data_Set.csv")
df_test
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                 2007          12                 1595          75.0
# 1                 2014           5                 1598          77.0
# 2                 2014           5                 1968         110.0
# 3                 2015           4                 1968         110.0
# 4                 2015           4                 1984         169.0
# ...                ...         ...                  ...           ...
# 5610              2011           8                 1968         103.0
# 5611              2005          14                 1896          96.0
# 5612              2005          14                 1896          77.0
# 5613              2011           8                 1997         104.0
# 5614              2011           8                 1396          80.0
#
#      body_type  Vroom Audit Rating transmission  door_count  seat_count  \
# 0          NaN                   5          man         4.0         5.0
# 1          NaN                   4          man         4.0         5.0
# 2          NaN                   5          man         5.0         5.0
# 3          NaN                   8         auto         4.0         5.0
# 4          NaN                   4         auto         2.0         NaN
# ...        ...                 ...          ...         ...         ...
# 5610       NaN                   8          man         4.0         5.0
# 5611       NaN                   6          man         4.0         5.0
# 5612       NaN                   7          man         5.0         5.0
# 5613       NaN                   5          man         4.0         7.0
# 5614       NaN                   4          man         NaN         NaN
#
#      fuel_type
# 0       petrol
# 1       diesel
# 2       diesel
# 3       diesel
# 4       petrol
# ...        ...
# 5610    diesel
# 5611    diesel
# 5612    diesel
# 5613    petrol
# 5614    petrol
#
# [5615 rows x 16 columns]

# %%
df_test.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
df_test.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type'],
#       dtype='object')

# %%
df_test.drop(columns='body_type',inplace=True)

# %%
df_test['Distance '].mean()
# Out:
# 95890.0885729907

# %%
df_test['Distance '].median()
# Out:
# 64000.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_test['Distance '].fillna(df['Distance '].median(),inplace=True)

# %%
df_test['engine_power'].mean()
# Out:
# 99.47457315953736

# %%
df_test['engine_power'].median()
# Out:
# 88.0

# %%
df_test['engine_power'].fillna(df['engine_power'].median(),inplace=True)

# %%
df_test['door_count'].mean()
# Out:
# 3.9783738823040133

# %%
df_test['door_count'].fillna(df['door_count'].mean(),inplace=True)

# %%
df_test['seat_count'].mean()
# Out:
# 4.884843353090601

# %%
df_test['seat_count'].fillna(df['seat_count'].mean(),inplace=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_test.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_test.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_test['Maker']=le.fit_transform(df_test['Maker'])

# %%
df_test['model']=le.fit_transform(df_test['model'])

# %%
df_test['Location']=le.fit_transform(df_test['Location'])

# %%
df_test['Owner Type']=le.fit_transform(df_test['Owner Type'])

# %%
df_test['transmission']=le.fit_transform(df_test['transmission'])

# %%
df_test['fuel_type']=le.fit_transform(df_test['fuel_type'])

# %%
df_test.dtypes
# Out:
# Id                       int64
# Maker                    int32
# model                    int32
# Location                 int32
# Distance               float64
# Owner Type               int32
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int32
# door_count             float64
# seat_count             float64
# fuel_type                int32
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df_test.boxplot()
plt.show()

# %%
z=(df_test-df_test.mean())/df_test.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   0.179475   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.215564    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.211676    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.283441   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -0.290809    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   0.179397   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700   0.775518   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   0.444092    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.103874    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077  -0.066147    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -0.736224    0.736224            -0.200189     -0.543264
# 1             0.741450   -0.741450            -0.198050     -0.498625
# 2             0.741450   -0.741450             0.065695      0.237907
# 3             0.952546   -0.952546             0.065695      0.237907
# 4             0.952546   -0.952546             0.077100      1.554737
# ...                ...         ...                  ...           ...
# 5610          0.108161   -0.108161             0.065695      0.081673
# 5611         -1.158416    1.158416             0.014371     -0.074561
# 5612         -1.158416    1.158416             0.014371     -0.498625
# 5613          0.108161   -0.108161             0.086366      0.103992
# 5614          0.108161   -0.108161            -0.342041     -0.431668
#
#       Vroom Audit Rating  transmission  door_count  seat_count  fuel_type
# 0              -0.711481      0.665022    0.033429    0.225164   1.027172
# 1              -1.426273      0.665022    0.033429    0.225164  -0.973373
# 2              -0.711481      0.665022    1.526071    0.225164  -0.973373
# 3               1.432892     -1.503443    0.033429    0.225164  -0.973373
# 4              -1.426273     -1.503443   -2.951855    0.002069   1.027172
# ...                  ...           ...         ...         ...        ...
# 5610            1.432892      0.665022    0.033429    0.225164  -0.973373
# 5611            0.003310      0.665022    0.033429    0.225164  -0.973373
# 5612            0.718101      0.665022    1.526071    0.225164  -0.973373
# 5613           -0.711481      0.665022    0.033429    4.142503   1.027172
# 5614           -1.426273      0.665022   -0.006856    0.002069   1.027172
#
# [5615 rows x 15 columns]

# %%
df4=df_test[(z>-2)&(z<2)]

# %%
df4.boxplot()
plt.show()

# %%
z=(df4-df4.mean())/df4.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   0.905548   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.677897    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.662315    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.949970   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -0.979506    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   0.905233   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700   3.294684   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   1.966219    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.230210    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077  -0.078986    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.163674    1.163674            -0.330625     -0.553189
# 1             0.782382   -0.782382            -0.325082     -0.494070
# 2             0.782382   -0.782382             0.358512      0.481400
# 3             1.060390   -1.060390             0.358512      0.481400
# 4             1.060390   -1.060390             0.388073      2.225421
# ...                ...         ...                  ...           ...
# 5610         -0.051642    0.051642             0.358512      0.274482
# 5611         -1.719690    1.719690             0.225488      0.067564
# 5612         -1.719690    1.719690             0.225488     -0.494070
# 5613         -0.051642    0.051642             0.412091      0.304042
# 5614         -0.051642    0.051642            -0.698288     -0.405391
#
#       Vroom Audit Rating  transmission  door_count  seat_count  fuel_type
# 0              -0.711481      0.665022   -0.388066    0.372516   1.027172
# 1              -1.426273      0.665022   -0.388066    0.372516  -0.973373
# 2              -0.711481      0.665022    2.351266    0.372516  -0.973373
# 3               1.432892     -1.503443   -0.388066    0.372516  -0.973373
# 4              -1.426273     -1.503443         NaN   -0.042721   1.027172
# ...                  ...           ...         ...         ...        ...
# 5610            1.432892      0.665022   -0.388066    0.372516  -0.973373
# 5611            0.003310      0.665022   -0.388066    0.372516  -0.973373
# 5612            0.718101      0.665022    2.351266    0.372516  -0.973373
# 5613           -0.711481      0.665022   -0.388066         NaN   1.027172
# 5614           -1.426273      0.665022   -0.461999   -0.042721   1.027172
#
# [5615 rows x 15 columns]

# %%
df5=df4[(z>-2)&(z<2)]

# %%
df5.boxplot()
plt.show()

# %%
z=(df5-df5.mean())/df5.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   1.187138   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.663742    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.645529    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.981767   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -1.016291    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   1.186769   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700        NaN   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   2.426950    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.140444    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077   0.036322    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.372554    1.372554            -0.151022     -0.528147
# 1             0.769024   -0.769024            -0.142597     -0.456711
# 2             0.769024   -0.769024             0.896549      0.721982
# 3             1.074963   -1.074963             0.896549      0.721982
# 4             1.074963   -1.074963             0.941485           NaN
# ...                ...         ...                  ...           ...
# 5610         -0.148795    0.148795             0.896549      0.471956
# 5611         -1.984433    1.984433             0.694337      0.221930
# 5612         -1.984433    1.984433             0.694337     -0.456711
# 5613         -0.148795    0.148795             0.977996      0.507674
# 5614         -0.148795    0.148795            -0.709914     -0.349557
#
#       Vroom Audit Rating  transmission  door_count  seat_count  fuel_type
# 0              -0.711481      0.665022    0.474236    0.466126   1.027172
# 1              -1.426273      0.665022    0.474236    0.466126  -0.973373
# 2              -0.711481      0.665022         NaN    0.466126  -0.973373
# 3               1.432892     -1.503443    0.474236    0.466126  -0.973373
# 4              -1.426273     -1.503443         NaN   -2.144912   1.027172
# ...                  ...           ...         ...         ...        ...
# 5610            1.432892      0.665022    0.474236    0.466126  -0.973373
# 5611            0.003310      0.665022    0.474236    0.466126  -0.973373
# 5612            0.718101      0.665022         NaN    0.466126  -0.973373
# 5613           -0.711481      0.665022    0.474236         NaN   1.027172
# 5614           -1.426273      0.665022   -2.108174   -2.144912   1.027172
#
# [5615 rows x 15 columns]

# %%
df6=df5[(z>-2)&(z<2)]

# %%
df6.boxplot()
plt.show()

# %%
df5.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                249
# Owner Type                0
# manufacture_year        485
# Age of car              485
# engine_displacement     540
# engine_power            559
# Vroom Audit Rating        0
# transmission              0
# door_count             1226
# seat_count              624
# fuel_type                 0
# dtype: int64

# %%
df5.dropna(inplace=True)

# %%
df5.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df5.shape
# Out:
# (3243, 15)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
data_test=pd.DataFrame(ss.fit_transform(df5),columns=df5.columns)
data_test
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.733322  0.593923 -0.551253  1.261447   1.517648   -1.291161
# 1    -1.732704  0.593923  0.405426 -0.633938  -0.504504    1.345084
# 2    -1.731469 -1.905871 -0.232360 -0.318040  -0.851956   -0.412413
# 3    -1.728997 -1.905871 -0.232360 -1.265733  -0.695212    1.345084
# 4    -1.728379  0.593923 -0.551253 -1.265733  -0.992440   -0.412413
# ...        ...       ...       ...       ...        ...         ...
# 3238  1.728813 -1.489239  1.202658  1.261447   0.597819   -1.291161
# 3239  1.729431  0.593923 -1.348485 -0.002143   0.549354    1.345084
# 3240  1.731285  0.593923  0.724318  1.261447   1.724232   -0.412413
# 3241  1.733139  0.593923 -0.551253  1.261447   1.517246   -1.291161
# 3242  1.735610 -0.655974 -1.029592  0.313754   0.260341    0.466335
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.654051    1.654051            -0.239664     -0.742327
# 1             0.651242   -0.651242            -0.230503     -0.664063
# 2             0.980569   -0.980569             0.899379      0.627296
# 3             0.651242   -0.651242             0.899379      1.409937
# 4            -1.983378    1.983378             0.997099      0.353371
# ...                ...         ...                  ...           ...
# 3238         -0.336741    0.336741             0.981830      1.605598
# 3239         -0.007413    0.007413            -2.059690     -1.524969
# 3240         -0.007413    0.007413             0.899379      0.353371
# 3241         -0.336741    0.336741             0.899379      0.353371
# 3242         -0.336741    0.336741            -0.847357     -0.546667
#
#       Vroom Audit Rating  transmission  door_count  seat_count  fuel_type
# 0              -0.705205      0.646541    0.435995    0.455874   1.100288
# 1              -1.420557      0.646541    0.435995    0.455874  -0.908853
# 2               1.440851     -1.546693    0.435995    0.455874  -0.908853
# 3               0.010147     -1.546693    0.435995    0.455874  -0.908853
# 4              -0.705205      0.646541   -2.293604   -2.193588   1.100288
# ...                  ...           ...         ...         ...        ...
# 3238            0.725499      0.646541    0.435995    0.455874  -0.908853
# 3239            0.010147      0.646541    0.435995   -2.193588   1.100288
# 3240            0.725499     -1.546693    0.435995    0.455874  -0.908853
# 3241            1.440851      0.646541    0.435995    0.455874  -0.908853
# 3242           -1.420557      0.646541   -2.293604   -2.193588   1.100288
#
# [3243 rows x 15 columns]

# %%
data_test.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X_test=data_test[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
       'fuel_type']]

# %%
y_test_pred=pd.DataFrame(model.predict(X_test))
y_test_pred
# Out:
#              0
# 0    -1.895223
# 1     0.081139
# 2     1.643869
# 3     1.832901
# 4    -0.428239
# ...        ...
# 3238  0.931599
# 3239 -1.597453
# 3240 -0.093691
# 3241 -0.503974
# 3242 -0.783084
#
# [3243 rows x 1 columns]

# %%
y_test_pred.shape
# Out:
# (3243, 1)

# %%
final=pd.concat([data_test['Id'],y_test_pred],axis=1)
final
# Out:
#             Id         0
# 0    -1.733322 -1.895223
# 1    -1.732704  0.081139
# 2    -1.731469  1.643869
# 3    -1.728997  1.832901
# 4    -1.728379 -0.428239
# ...        ...       ...
# 3238  1.728813  0.931599
# 3239  1.729431 -1.597453
# 3240  1.731285 -0.093691
# 3241  1.733139 -0.503974
# 3242  1.735610 -0.783084
#
# [3243 rows x 2 columns]

# %%
final.to_csv("E:\PYTHON Durga Fill\python  my project.csv") #       'E:\PYTHON Durga Fill\python  my project.csv')
